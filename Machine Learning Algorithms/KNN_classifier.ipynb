# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X_data = []
Y_data = []

for i in range(500):
    x = np.random.randint(1, 80, 2)
    X_data.append(x)
    Y_data.append(np.ones(1))

# %%
for i in range(500):
    x = np.random.randint(-100, -5, 2)
    X_data.append(x)
    Y_data.append(np.zeros(1))

# %%
X_data
# Out:
# array([[ 38,  38],
#        [ 78,  77],
#        [ 10,  42],
#        ...,
#        [-82, -85],
#        [ -9, -18],
#        [-60, -45]])

# %%
X_data = np.array(X_data)
Y_data = np.array(Y_data)

# %%
Y_data.shape
# Out:
# (1000, 1)

# %%
plt.scatter(X_data[:, 0], X_data[:, 1], c = Y_data)

# %%
print(X_data.shape, Y_data.shape)
# Out:
# (1000, 2) (1000, 1)

# %%
import sklearn
dataset_X, dataset_Y = sklearn.utils.shuffle(X_data, Y_data, random_state=5)

# %%
print(dataset_X.shape, dataset_Y.shape)
# Out:
# (1000, 2) (1000, 1)

# %%
dataset = np.hstack((X_data, Y_data))

# %%
dataset.shape
# Out:
# (1000, 3)

# %%
np.random.seed(5)
np.random.shuffle(dataset)

# %%
datasetX = dataset[:, :2]
datasetY = dataset[:, 2]

# %%
datasetY = datasetY.reshape((-1, 1))
print(datasetY.shape, datasetX.shape)
# Out:
# (1000, 1) (1000, 2)

# %%
train_X = datasetX[:800, :]
train_Y = datasetY[:800, :]
test_X = datasetX[800:, :]
test_Y = datasetY[800:, :]

# %%
print(train_X.shape, train_Y.shape, test_X.shape, test_Y.shape)
# Out:
# (800, 2) (800, 1) (200, 2) (200, 1)

# %%
def distance_formula(p1, p2):
    dist = ((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)**0.5
    return dist

# %%
print(distance_formula([10, 10], [10, 0]))
print(distance_formula(train_X[0], train_X[1]))
# Out:
# 10.0
# 11.661903789690601

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('bmh')

# %%
class KNN:
    
    def __init__(self, k, X, Y):
        self.k = k
        self.X = X
        self.Y = Y
        
    def distance_formula(self, p1, p2):
        dist = ((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)**0.5
        return dist
    
    def predict(self, point):
        
        distance = []
        
        for i in range(self.X.shape[0]):
            distance.append((self.distance_formula(self.X[i], point), i))
            
        distance = sorted(distance)
        top_distance = distance[:self.k]
        
        classes = []
        
        for _, i in top_distance:
            classes.append(self.Y[i])
            
        unique_class, count_class = np.unique(classes, return_counts=True)
        
        pred_class = np.argmax(count_class)
        
        return unique_class[pred_class], np.max(count_class)/np.sum(count_class)

# %%
# arr = np.array([1,3,3,3,2,2,3,4,2,1,4,3,2,1,3,4,2,12,4,2,3,3])
# unique_elements, count_element = np.unique(arr, return_counts=True)
# print(unique_elements, count_element, np.argmax(count_element), unique_elements[np.argmax(count_element)])
# Out:
# [ 1  2  3  4 12] [3 6 8 4 1] 2 3

# %%
knn_classifier = KNN(5, train_X, train_Y)

# %%
pred_class, pred_prob = knn_classifier.predict(test_X[0])

# %%
print(pred_class, pred_prob, test_Y[0])
# Out:
# 0.0 1.0 [0.]

# %%
Y_pred = []

for i in range(test_X.shape[0]):
    pred, prob = knn_classifier.predict(test_X[i])
    Y_pred.append(pred)
    print(f'The {i}th test case belongs to {pred} and its label is {test_Y[i]} with prob={prob}')
# Out:
# The 0th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 1th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 2th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 3th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 4th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 5th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 6th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 7th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 8th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 9th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 10th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 11th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 12th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 13th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 14th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 15th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 16th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 17th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 18th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 19th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 20th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 21th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 22th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 23th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 24th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 25th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 26th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 27th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 28th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 29th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 30th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 31th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 32th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 33th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 34th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 35th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 36th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 37th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 38th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 39th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 40th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 41th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 42th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 43th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 44th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 45th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 46th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 47th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 48th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 49th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 50th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 51th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 52th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 53th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 54th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 55th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 56th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 57th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 58th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 59th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 60th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 61th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 62th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 63th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 64th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 65th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 66th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 67th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 68th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 69th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 70th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 71th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 72th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 73th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 74th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 75th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 76th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 77th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 78th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 79th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 80th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 81th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 82th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 83th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 84th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 85th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 86th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 87th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 88th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 89th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 90th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 91th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 92th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 93th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 94th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 95th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 96th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 97th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 98th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 99th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 100th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 101th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 102th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 103th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 104th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 105th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 106th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 107th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 108th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 109th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 110th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 111th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 112th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 113th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 114th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 115th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 116th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 117th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 118th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 119th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 120th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 121th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 122th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 123th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 124th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 125th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 126th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 127th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 128th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 129th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 130th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 131th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 132th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 133th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 134th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 135th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 136th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 137th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 138th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 139th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 140th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 141th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 142th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 143th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 144th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 145th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 146th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 147th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 148th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 149th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 150th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 151th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 152th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 153th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 154th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 155th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 156th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 157th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 158th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 159th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 160th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 161th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 162th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 163th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 164th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 165th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 166th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 167th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 168th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 169th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 170th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 171th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 172th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 173th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 174th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 175th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 176th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 177th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 178th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 179th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 180th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 181th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 182th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 183th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 184th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 185th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 186th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 187th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 188th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 189th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 190th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 191th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 192th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 193th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 194th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 195th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 196th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 197th test case belongs to 0.0 and its label is [0.] with prob=1.0
# The 198th test case belongs to 1.0 and its label is [1.] with prob=1.0
# The 199th test case belongs to 0.0 and its label is [0.] with prob=1.0

# %%
Y_pred = np.array(Y_pred)

# %%
def accuracy(pred, label):
    temp = 0
    
    for i in range(pred.shape[0]):
        if pred[i]==label[i]:
            temp+=1
        else:
            pass
    print("Accuracy = ", (temp/pred.shape[0])*100, "%", sep='')
    return (temp/pred.shape[0])*100

# %%
accuracy(Y_pred, test_Y)
# Out:
# Accuracy = 100.0%
# 100.0

# %%
pred, prob = knn_classifier.predict([-3, -3])
print(f'The random test case belongs to {pred} with prob={prob}')
# Out:
# The random test case belongs to 0.0 with prob=0.6
